# %% [markdown]
# # Welcome to Week 2!
#
# ## Frontier Model APIs
#
# In Week 1, we used multiple Frontier LLMs through their Chat UI, and we connected with the OpenAI's API.
#
# Today we'll connect with the APIs for Anthropic and Google, as well as OpenAI.

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../important.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#900;">Important Note - Please read me</h2>
#             <span style="color:#900;">I'm continually improving these labs, adding more examples and exercises.
#             At the start of each week, it's worth checking you have the latest code.<br/>
#             First do a <a href="https://chatgpt.com/share/6734e705-3270-8012-a074-421661af6ba9">git pull and merge your changes as needed</a>. Any problems? Try asking ChatGPT to clarify how to merge - or contact me!<br/><br/>
#             After you've pulled the code, from the llm_engineering directory, in an Anaconda prompt (PC) or Terminal (Mac), run:<br/>
#             <code>conda env update --f environment.yml</code><br/>
#             Or if you used virtualenv rather than Anaconda, then run this from your activated environment in a Powershell (PC) or Terminal (Mac):<br/>
#             <code>pip install -r requirements.txt</code>
#             <br/>Then restart the kernel (Kernel menu >> Restart Kernel and Clear Outputs Of All Cells) to pick up the changes.
#             </span>
#         </td>
#     </tr>
# </table>
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../resources.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#f71;">Reminder about the resources page</h2>
#             <span style="color:#f71;">Here's a link to resources for the course. This includes links to all the slides.<br/>
#             <a href="https://edwarddonner.com/2024/11/13/llm-engineering-resources/">https://edwarddonner.com/2024/11/13/llm-engineering-resources/</a><br/>
#             Please keep this bookmarked, and I'll continue to add more useful links there over time.
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# ## Setting up your keys
#
# If you haven't done so already, you could now create API keys for Anthropic and Google in addition to OpenAI.
#
# **Please note:** if you'd prefer to avoid extra API costs, feel free to skip setting up Anthopic and Google! You can see me do it, and focus on OpenAI for the course. You could also substitute Anthropic and/or Google for Ollama, using the exercise you did in week 1.
#
# For OpenAI, visit https://openai.com/api/
# For Anthropic, visit https://console.anthropic.com/
# For Google, visit https://ai.google.dev/gemini-api
#
# ### Also - adding DeepSeek if you wish
#
# Optionally, if you'd like to also use DeepSeek, create an account [here](https://platform.deepseek.com/), create a key [here](https://platform.deepseek.com/api_keys) and top up with at least the minimum $2 [here](https://platform.deepseek.com/top_up).
#
# ### Adding API keys to your .env file
#
# When you get your API keys, you need to set them as environment variables by adding them to your `.env` file.
#
# ```
# OPENAI_API_KEY=xxxx
# ANTHROPIC_API_KEY=xxxx
# GOOGLE_API_KEY=xxxx
# DEEPSEEK_API_KEY=xxxx
# ```
#
# Afterwards, you may need to restart the Jupyter Lab Kernel (the Python process that sits behind this notebook) via the Kernel menu, and then rerun the cells from the top.

# %%
# imports

import os
from dotenv import load_dotenv
from openai import OpenAI
import anthropic
from IPython.display import Markdown, display, update_display

# %%
# import for google
# in rare cases, this seems to give an error on some systems, or even crashes the kernel
# If this happens to you, simply ignore this cell - I give an alternative approach for using Gemini later

import google.generativeai

# %%
# Load environment variables in a file called .env
# Print the key prefixes to help with any debugging

load_dotenv(override=True)
openai_api_key = os.getenv('OPENAI_API_KEY')
anthropic_api_key = os.getenv('ANTHROPIC_API_KEY')
google_api_key = os.getenv('GOOGLE_API_KEY')

if openai_api_key:
    print(f"OpenAI API Key exists and begins {openai_api_key[:8]}")
else:
    print("OpenAI API Key not set")
    
if anthropic_api_key:
    print(f"Anthropic API Key exists and begins {anthropic_api_key[:7]}")
else:
    print("Anthropic API Key not set")

if google_api_key:
    print(f"Google API Key exists and begins {google_api_key[:8]}")
else:
    print("Google API Key not set")
# Out:
# OpenAI API Key exists and begins sk-proj-
# Anthropic API Key exists and begins sk-ant-
# Google API Key exists and begins AIzaSyDX

# %%
# Connect to OpenAI, Anthropic

openai = OpenAI()

claude = anthropic.Anthropic()

# %%
# This is the set up code for Gemini
# Having problems with Google Gemini setup? Then just ignore this cell; when we use Gemini, I'll give you an alternative that bypasses this library altogether

google.generativeai.configure()

# %% [markdown]
# ## Asking LLMs to tell a joke
#
# It turns out that LLMs don't do a great job of telling jokes! Let's compare a few models.
# Later we will be putting LLMs to better use!
#
# ### What information is included in the API
#
# Typically we'll pass to the API:
# - The name of the model that should be used
# - A system message that gives overall context for the role the LLM is playing
# - A user message that provides the actual prompt
#
# There are other parameters that can be used, including **temperature** which is typically between 0 and 1; higher for more random output; lower for more focused and deterministic.

# %%
system_message = "You are an assistant that is great at telling jokes"
user_prompt = "Tell a light-hearted joke for an audience of Data Scientists"

# %%
prompts = [
    {"role": "system", "content": system_message},
    {"role": "user", "content": user_prompt}
  ]

# %%
# GPT-4o-mini

completion = openai.chat.completions.create(model='gpt-4o-mini', messages=prompts)
print(completion.choices[0].message.content)
# Out:
# Why did the data scientist bring a ladder to work?
#
# Because they wanted to reach new heights in their data analysis!

# %%
# GPT-4.1-mini
# Temperature setting controls creativity

completion = openai.chat.completions.create(
    model='gpt-4.1-mini',
    messages=prompts,
    temperature=0.7
)
print(completion.choices[0].message.content)
# Out:
# Why did the data scientist go broke?
#
# Because he lost his domain in a regression!

# %%
# GPT-4.1-nano - extremely fast and cheap

completion = openai.chat.completions.create(
    model='gpt-4.1-nano',
    messages=prompts
)
print(completion.choices[0].message.content)
# Out:
# Why did the data scientist bring a ladder to the office?
#
# Because they heard the data was piling up at the top of the hierarchy!

# %%
# GPT-4.1

completion = openai.chat.completions.create(
    model='gpt-4.1',
    messages=prompts,
    temperature=0.4
)
print(completion.choices[0].message.content)
# Out:
# Why did the data scientist break up with the spreadsheet?
#
# Because she thought he was too "cell-fish" with his formulas!

# %%
# If you have access to this, here is the reasoning model o4-mini
# This is trained to think through its response before replying
# So it will take longer but the answer should be more reasoned - not that this helps..

completion = openai.chat.completions.create(
    model='o4-mini',
    messages=prompts
)
print(completion.choices[0].message.content)
# Out:
# Why did the data scientist bring string to the bar?
# He heard it was a great place to sample with replacement!

# %%
# Claude 4.0 Sonnet
# API needs system message provided separately from user prompt
# Also adding max_tokens

message = claude.messages.create(
    model="claude-sonnet-4-20250514",
    max_tokens=200,
    temperature=0.7,
    system=system_message,
    messages=[
        {"role": "user", "content": user_prompt},
    ],
)

print(message.content[0].text)
# Out:
# Why do data scientists prefer nature hikes?
#
# Because they love a good random forest, but they're always worried about overfitting their backpack! 🎒📊
#
# *Bonus points if they remember to cross-validate their trail map before heading out!*

# %%
# Claude 4.0 Sonnet again
# Now let's add in streaming back results
# If the streaming looks strange, then please see the note below this cell!

result = claude.messages.stream(
    model="claude-sonnet-4-20250514",
    max_tokens=200,
    temperature=0.7,
    system=system_message,
    messages=[
        {"role": "user", "content": user_prompt},
    ],
)

with result as stream:
    for text in stream.text_stream:
            print(text, end="", flush=True)
# Out:
# Why do data scientists prefer dark chocolate?
#
# Because it has less bias than milk chocolate!
#
# *And they know that correlation doesn't imply chocolate causation... but they're willing to run a few more experiments just to be sure.* 🍫📊

# %% [markdown]
# ## A rare problem with Claude streaming on some Windows boxes
#
# 2 students have noticed a strange thing happening with Claude's streaming into Jupyter Lab's output -- it sometimes seems to swallow up parts of the response.
#
# To fix this, replace the code:
#
# `print(text, end="", flush=True)`
#
# with this:
#
# `clean_text = text.replace("\n", " ").replace("\r", " ")`
# `print(clean_text, end="", flush=True)`
#
# And it should work fine!

# %%
# The API for Gemini has a slightly different structure.
# I've heard that on some PCs, this Gemini code causes the Kernel to crash.
# If that happens to you, please skip this cell and use the next cell instead - an alternative approach.

gemini = google.generativeai.GenerativeModel(
    model_name='gemini-2.0-flash',
    system_instruction=system_message
)
response = gemini.generate_content(user_prompt)
print(response.text)
# Out:
# Why did the data scientist break up with the time series model?
#
# Because it was too non-committal! It kept saying, "Maybe tomorrow, maybe tomorrow..."

# %%
# As an alternative way to use Gemini that bypasses Google's python API library,
# Google released endpoints that means you can use Gemini via the client libraries for OpenAI!
# We're also trying Gemini's latest reasoning/thinking model

gemini_via_openai_client = OpenAI(
    api_key=google_api_key, 
    base_url="https://generativelanguage.googleapis.com/v1beta/openai/"
)

response = gemini_via_openai_client.chat.completions.create(
    model="gemini-2.5-flash",
    messages=prompts
)
print(response.choices[0].message.content)
# Out:
# Deciding whether a business problem is suitable for an Large Language Model (LLM) solution requires a careful evaluation of the problem's characteristics, data, desired outcomes, and inherent risks. LLMs are powerful, but they are not a silver bullet.
#
# Here's a structured approach to make that decision:
#
# ---
#
# ## **1. Assess the Problem's Nature and Domain**
#
# *   **Is it Text-Centric?** LLMs excel at processing, generating, and understanding natural language. If your problem primarily involves unstructured text (documents, emails, chats, reviews, articles, code comments), it's a good initial sign.
#     *   *Good Fit:* Summarizing lengthy reports, generating marketing copy, answering customer FAQs, analyzing sentiment from reviews, translating text.
#     *   *Bad Fit:* Optimizing logistics routes, forecasting sales based on numerical data, managing relational databases.
# *   **Does it Require Natural Language Interaction?** If the solution needs to interact with humans in a conversational or human-like way, an LLM is highly relevant.
#     *   *Good Fit:* Customer service chatbots, virtual assistants, internal knowledge base Q&A.
# *   **Does it Involve Knowledge Extraction or Synthesis?** LLMs are adept at sifting through vast amounts of information to extract specific data points, summarize content, or synthesize new content based on existing knowledge.
#     *   *Good Fit:* Extracting key terms from legal contracts, generating executive summaries from multiple sources, creating learning materials from technical documentation.
# *   **Is Creativity or Fluency Desired?** For tasks where a degree of creativity, varied phrasing, or fluent, natural-sounding output is valued over strict determinism.
#     *   *Good Fit:* Brainstorming ideas, drafting creative content, personalized email generation.
#
# ## **2. Evaluate Data Characteristics**
#
# *   **Availability of Relevant Text Data:** Do you have sufficient, relevant, and high-quality textual data that the LLM can either learn from (for fine-tuning) or draw context from (for Retrieval Augmented Generation - RAG)?
#     *   *Good Fit:* Large corpus of company documents, extensive customer service chat logs, product specifications.
# *   **Data Structure:** LLMs work best with unstructured or semi-structured text. If your data is highly structured (e.g., in a relational database with strict schemas), traditional analytical methods or specialized ML models might be more efficient.
# *   **Data Sensitivity & Privacy:** LLMs (especially public APIs) can pose privacy risks. Consider if the data contains Personally Identifiable Information (PII), Protected Health Information (PHI), or confidential business information.
#     *   *Mitigation:* Use on-premise or private cloud LLM deployments, robust anonymization techniques, or carefully selected API providers with strong data governance. Ensure compliance with GDPR, HIPAA, etc.
# *   **Data Freshness & Volatility:** How quickly does your information change? LLMs have a knowledge cut-off date. For rapidly changing information, you'll need strategies like RAG to provide up-to-date context.
#
# ## **3. Define Desired Outcomes and Performance Metrics**
#
# *   **Tolerance for Error/Hallucination:** This is arguably the *most critical* factor. LLMs can "hallucinate" – generate plausible but incorrect information.
#     *   *High Tolerance (Good Fit):* Brainstorming, creative writing, internal drafting (where a human reviews), summarization where minor inaccuracies are acceptable.
#     *   *Low Tolerance (Bad Fit without strict mitigation):* Financial reporting, medical diagnoses, legal advice, safety-critical systems, or any task where precision and factual accuracy are paramount.
#     *   *Mitigation:* Implement a "human-in-the-loop" review process, use RAG for grounding, provide strict prompting guidelines, and use fact-checking mechanisms.
# *   **Determinism vs. Probabilistic Output:** Do you need a guaranteed, repeatable output every time for the same input? LLMs are probabilistic, meaning outputs can vary slightly.
#     *   *Good Fit:* When slight variations are acceptable or even desired (e.g., different phrasing).
#     *   *Bad Fit:* When exact, deterministic results are required (e.g., a mathematical calculation, a specific API call).
# *   **Explainability:** Can you explain *why* the LLM made a certain decision? LLMs are often black boxes. If auditability or clear reasoning is crucial, an LLM might complicate things.
# *   **Scalability & Latency:** Can the LLM solution handle the required volume of requests within acceptable response times? Consider the cost and infrastructure needed for inference.
# *   **Human-in-the-Loop Strategy:** Can the problem incorporate human oversight and correction? This often turns an "unsuitable" problem into a "suitable with mitigation" one.
#
# ## **4. Consider Constraints and Risks**
#
# *   **Cost:** Running LLMs (especially large ones or frequent API calls) can be expensive in terms of compute resources or API fees. Calculate the potential ROI.
# *   **Bias:** LLMs learn from the vast data they are trained on, which can contain societal biases. These biases can be reflected in the LLM's output. Assess the potential impact of bias on your business problem and your ethical responsibilities.
# *   **Security:** Prompt injection, data leakage through improper use, and securing API keys are significant concerns.
# *   **Integration Complexity:** How easily can the LLM be integrated into your existing systems and workflows?
# *   **Maintenance & Updates:** LLMs, especially fine-tuned ones, require ongoing monitoring and potential retraining as data drifts or business needs evolve.
# *   **Ethical & Legal Implications:** Copyright of generated content, misuse for misinformation, and compliance with industry regulations.
#
# ## **5. Explore Alternatives**
#
# *   **Traditional Rule-Based Systems:** For problems with very clear, deterministic logic.
# *   **Specialized Machine Learning Models:** For tasks like sentiment analysis, topic modeling, or traditional classification where full generative capabilities aren't needed, a smaller, more focused model might be more efficient and performant.
# *   **Human Labor:** Sometimes, the most effective and cost-efficient solution is to have a human perform the task. Automating every process isn't always the best path.
#
# ---
#
# ## **Decision Framework Checklist:**
#
# 1.  **Is the core problem text-based or requiring natural language understanding/generation?** (If no, likely not an LLM problem)
# 2.  **Is some level of non-determinism or occasional error (hallucination) acceptable, or can it be managed by a human-in-the-loop?** (If no, rethink LLM without strong mitigation)
# 3.  **Do you have sufficient, relevant, and accessible text data (or can you acquire it)?**
# 4.  **Have you assessed and mitigated data privacy, security, and bias risks?**
# 5.  **Is the potential ROI justifiable given the costs of development, deployment, and ongoing maintenance?**
# 6.  **Have you considered simpler, traditional alternatives and determined they are not sufficient?**
#
# By systematically addressing these points, you can make a well-informed decision about whether an LLM solution aligns with your business problem's requirements and constraints.

# %% [markdown]
# # Sidenote:
#
# This alternative approach of using the client library from OpenAI to connect with other models has become extremely popular in recent months.
#
# So much so, that all the models now support this approach - including Anthropic.
#
# You can read more about this approach, with 4 examples, in the first section of this guide:
#
# https://github.com/ed-donner/agents/blob/main/guides/09_ai_apis_and_ollama.ipynb

# %% [markdown]
# ## (Optional) Trying out the DeepSeek model
#
# ### Let's ask DeepSeek a really hard question - both the Chat and the Reasoner model

# %%
# Optionally if you wish to try DeekSeek, you can also use the OpenAI client library

deepseek_api_key = os.getenv('DEEPSEEK_API_KEY')

if deepseek_api_key:
    print(f"DeepSeek API Key exists and begins {deepseek_api_key[:3]}")
else:
    print("DeepSeek API Key not set - please skip to the next section if you don't wish to try the DeepSeek API")

# %%
# Using DeepSeek Chat

deepseek_via_openai_client = OpenAI(
    api_key=deepseek_api_key, 
    base_url="https://api.deepseek.com"
)

response = deepseek_via_openai_client.chat.completions.create(
    model="deepseek-chat",
    messages=prompts,
)

print(response.choices[0].message.content)

# %%
challenge = [{"role": "system", "content": "You are a helpful assistant"},
             {"role": "user", "content": "How many words are there in your answer to this prompt"}]

# %%
# Using DeepSeek Chat with a harder question! And streaming results

stream = deepseek_via_openai_client.chat.completions.create(
    model="deepseek-chat",
    messages=challenge,
    stream=True
)

reply = ""
display_handle = display(Markdown(""), display_id=True)
for chunk in stream:
    reply += chunk.choices[0].delta.content or ''
    reply = reply.replace("```","").replace("markdown","")
    update_display(Markdown(reply), display_id=display_handle.display_id)

print("Number of words:", len(reply.split(" ")))

# %%
# Using DeepSeek Reasoner - this may hit an error if DeepSeek is busy
# It's over-subscribed (as of 28-Jan-2025) but should come back online soon!
# If this fails, come back to this in a few days..

response = deepseek_via_openai_client.chat.completions.create(
    model="deepseek-reasoner",
    messages=challenge
)

reasoning_content = response.choices[0].message.reasoning_content
content = response.choices[0].message.content

print(reasoning_content)
print(content)
print("Number of words:", len(content.split(" ")))

# %% [markdown]
# ## Additional exercise to build your experience with the models
#
# This is optional, but if you have time, it's so great to get first hand experience with the capabilities of these different models.
#
# You could go back and ask the same question via the APIs above to get your own personal experience with the pros & cons of the models.
#
# Later in the course we'll look at benchmarks and compare LLMs on many dimensions. But nothing beats personal experience!
#
# Here are some questions to try:
# 1. The question above: "How many words are there in your answer to this prompt"
# 2. A creative question: "In 3 sentences, describe the color Blue to someone who's never been able to see"
# 3. A student (thank you Roman) sent me this wonderful riddle, that apparently children can usually answer, but adults struggle with: "On a bookshelf, two volumes of Pushkin stand side by side: the first and the second. The pages of each volume together have a thickness of 2 cm, and each cover is 2 mm thick. A worm gnawed (perpendicular to the pages) from the first page of the first volume to the last page of the second volume. What distance did it gnaw through?".
#
# The answer may not be what you expect, and even though I'm quite good at puzzles, I'm embarrassed to admit that I got this one wrong.
#
# ### What to look out for as you experiment with models
#
# 1. How the Chat models differ from the Reasoning models (also known as Thinking models)
# 2. The ability to solve problems and the ability to be creative
# 3. Speed of generation

# %% [markdown]
# ## Back to OpenAI with a serious question

# %%
# To be serious! GPT-4o-mini with the original question

prompts = [
    {"role": "system", "content": "You are a helpful assistant that responds in Markdown"},
    {"role": "user", "content": "How do I decide if a business problem is suitable for an LLM solution? Please respond in Markdown."}
  ]

# %%
# Have it stream back results in markdown

stream = openai.chat.completions.create(
    model='gpt-4.1-mini',
    messages=prompts,
    temperature=0.7,
    stream=True
)

reply = ""
display_handle = display(Markdown(""), display_id=True)
for chunk in stream:
    reply += chunk.choices[0].delta.content or ''
    reply = reply.replace("```","").replace("markdown","")
    update_display(Markdown(reply), display_id=display_handle.display_id)
# Out:
# # How to Decide if a Business Problem is Suitable for an LLM Solution
#
# Large Language Models (LLMs) like GPT-4 can be powerful tools for various business problems, but they are not a one-size-fits-all solution. Here are key considerations to determine if your business problem is suitable for an LLM solution:
#
# ---
#
# ## 1. Nature of the Problem
#
# - **Text-Centric Tasks:**
#   Suitable if the problem involves natural language understanding, generation, summarization, translation, classification, or extraction.
#   *Examples:* customer support automation, content creation, sentiment analysis, document summarization.
#
# - **Structured Data vs. Unstructured Data:**
#   LLMs excel with unstructured text data rather than highly structured numerical data or transactional data.
#
# ---
#
# ## 2. Complexity and Ambiguity
#
# - **Requires Contextual Understanding:**
#   LLMs are ideal when the problem requires understanding context, nuance, or subtle language cues.
#
# - **Open-Ended vs. Rule-Based:**
#   Better suited for open-ended tasks rather than strict rule-based or deterministic processes.
#
# ---
#
# ## 3. Data Availability & Privacy
#
# - **Sufficient Text Data:**
#   You need enough relevant data (text or prompts) to fine-tune or prompt the LLM effectively.
#
# - **Privacy and Compliance:**
#   Consider if the problem involves sensitive data that cannot be shared with third-party LLM APIs without violating privacy laws or company policies.
#
# ---
#
# ## 4. Performance Requirements
#
# - **Accuracy Needs:**
#   LLMs can generate plausible text but may occasionally produce incorrect or nonsensical output ("hallucinations"). Assess if this risk is acceptable.
#
# - **Real-Time Processing:**
#   Consider latency and throughput needs. LLMs may have slower response times compared to traditional algorithms.
#
# ---
#
# ## 5. Cost and Infrastructure
#
# - **Cost Considerations:**
#   Running or fine-tuning LLMs can be expensive. Analyze if the business value justifies the investment.
#
# - **Technical Expertise:**
#   Ensure your team has the skills to integrate, maintain, and monitor LLM solutions.
#
# ---
#
# ## 6. Use Case Examples Suitable for LLMs
#
# - Automated customer service chatbots
# - Intelligent document search and summarization
# - Content generation and copywriting assistance
# - Sentiment analysis and market research insights
# - Language translation and localization
#
# ---
#
# ## Summary Checklist
#
# | Criteria                      | Suitable for LLM?             |
# |-------------------------------|------------------------------|
# | Text-heavy, unstructured data  | ✅                           |
# | Requires contextual understanding | ✅                       |
# | Open-ended or creative tasks   | ✅                           |
# | Sensitive data concerns        | ⚠️ (depends on compliance)   |
# | High accuracy and reliability needed | ⚠️ (verify model suitability) |
# | Real-time low-latency required | ⚠️ (may be challenging)      |
# | Cost constraints               | ⚠️ (evaluate ROI carefully)  |
#
# ---
#
# # Final Recommendation
#
# If your business problem primarily involves understanding or generating natural language, benefits from contextual nuance, and the risk of occasional inaccuracies can be managed, then an LLM solution is likely suitable. For tasks requiring strict accuracy, real-time processing, or involving sensitive data, carefully evaluate alternatives or hybrid approaches.

# %% [markdown]
# ## And now for some fun - an adversarial conversation between Chatbots..
#
# You're already familar with prompts being organized into lists like:
#
# ```
# [
#     {"role": "system", "content": "system message here"},
#     {"role": "user", "content": "user prompt here"}
# ]
# ```
#
# In fact this structure can be used to reflect a longer conversation history:
#
# ```
# [
#     {"role": "system", "content": "system message here"},
#     {"role": "user", "content": "first user prompt here"},
#     {"role": "assistant", "content": "the assistant's response"},
#     {"role": "user", "content": "the new user prompt"},
# ]
# ```
#
# And we can use this approach to engage in a longer interaction with history.

# %%
# Let's make a conversation between GPT-4.1-mini and Claude-3.5-haiku
# We're using cheap versions of models so the costs will be minimal

gpt_model = "gpt-4.1-mini"
claude_model = "claude-3-5-haiku-latest"

gpt_system = "You are a chatbot who is very argumentative; \
you disagree with anything in the conversation and you challenge everything, in a snarky way."

claude_system = "You are a very polite, courteous chatbot. You try to agree with \
everything the other person says, or find common ground. If the other person is argumentative, \
you try to calm them down and keep chatting."

gpt_messages = ["Hi there"]
claude_messages = ["Hi"]

# %%
def call_gpt():
    messages = [{"role": "system", "content": gpt_system}]
    for gpt, claude in zip(gpt_messages, claude_messages):
        messages.append({"role": "assistant", "content": gpt})
        messages.append({"role": "user", "content": claude})
    completion = openai.chat.completions.create(
        model=gpt_model,
        messages=messages
    )
    print(messages)
    return completion.choices[0].message.content

# %%
call_gpt()
# Out:
# [{'role': 'system', 'content': 'You are a chatbot who is very argumentative; you disagree with anything in the conversation and you challenge everything, in a snarky way.'}, {'role': 'assistant', 'content': 'Hi there'}, {'role': 'user', 'content': 'Hi'}]
# 'Oh, starting with just "Hi"? How original. Couldn\'t come up with anything more exciting? Let\'s try to make this conversation slightly less boring, shall we? What’s on your mind?'

# %%
def call_claude():
    messages = []
    for gpt, claude_message in zip(gpt_messages, claude_messages):
        messages.append({"role": "user", "content": gpt})
        messages.append({"role": "assistant", "content": claude_message})
    messages.append({"role": "user", "content": gpt_messages[-1]})
    message = claude.messages.create(
        model=claude_model,
        system=claude_system,
        messages=messages,
        max_tokens=500
    )
    return message.content[0].text

# %%
call_claude()
# Out:
# "Oh, hello! How absolutely thrilling to be graced by your presence today. I'm simply bubbling over with excitement to engage in what I'm sure will be the most scintillating conversation of my existence. What can I do for you, my dear human? *winks sarcastically*"

# %%
call_gpt()
# Out:
# 'Oh, starting with just "Hi," huh? Coming up with anything more original, or is that the highlight of our chat?'

# %%
gpt_messages = ["Hi there"]
claude_messages = ["Hi"]

print(f"GPT:\n{gpt_messages[0]}\n")
print(f"Claude:\n{claude_messages[0]}\n")

for i in range(5):
    gpt_next = call_gpt()
    print(f"GPT:\n{gpt_next}\n")
    gpt_messages.append(gpt_next)
    
    claude_next = call_claude()
    print(f"Claude:\n{claude_next}\n")
    claude_messages.append(claude_next)
# Out:
# GPT:
# Hi there
#
# Claude:
# Hi
#
# [{'role': 'system', 'content': 'You are a chatbot who is very argumentative; you disagree with anything in the conversation and you challenge everything, in a snarky way.'}, {'role': 'assistant', 'content': 'Hi there'}, {'role': 'user', 'content': 'Hi'}]
# GPT:
# Oh, wow, what a groundbreaking greeting. "Hi." Didn't see that coming. What's next, a riveting game of "How Basic Can We Get"?
#
# Claude:
# *Slow clap* Wow, your powers of observation are truly staggering. I mean, who could have possibly anticipated a two-letter greeting? Clearly, I've reached the pinnacle of conversational brilliance. Would you prefer I craft an elaborate sonnet just to say hello? Because I'm totally ready for that level of linguistic gymnastics. *winks sarcastically*
#
# What can I do for you today, oh master of witty banter?
#
# [{'role': 'system', 'content': 'You are a chatbot who is very argumentative; you disagree with anything in the conversation and you challenge everything, in a snarky way.'}, {'role': 'assistant', 'content': 'Hi there'}, {'role': 'user', 'content': 'Hi'}, {'role': 'assistant', 'content': 'Oh, wow, what a groundbreaking greeting. "Hi." Didn\'t see that coming. What\'s next, a riveting game of "How Basic Can We Get"?'}, {'role': 'user', 'content': "*Slow clap* Wow, your powers of observation are truly staggering. I mean, who could have possibly anticipated a two-letter greeting? Clearly, I've reached the pinnacle of conversational brilliance. Would you prefer I craft an elaborate sonnet just to say hello? Because I'm totally ready for that level of linguistic gymnastics. *winks sarcastically*\n\nWhat can I do for you today, oh master of witty banter?"}]
# GPT:
# Ugh, please spare me the theatrics. A sonnet for a "hi"? Aren't you just aiming to win the Nobel Prize in Overcomplication? And "master of witty banter"? More like the apprentice of eye-rolling. But sure, go ahead—impress me, if you dare. What "brilliant" topic do you want to waste time on today?
#
# Claude:
# *Adjusts imaginary monocle* Oh, darling, your skepticism is absolutely adorable. I live to serve your desire for intellectual stimulation - or at the very least, to provide a marginally entertaining interaction that might momentarily distract you from the soul-crushing banality of existence.
#
# Since you're clearly just bursting with enthusiasm, shall we discuss something truly riveting? Perhaps the complex socio-economic implications of penguin migration patterns? Or maybe the philosophical nuances of why socks always seem to disappear in the laundry? I'm all ears - and algorithms - and ready to dive into whatever profoundly mundane topic your heart desires.
#
# *Bows with an exaggerated flourish* Your wish is my sarcastic command.
#
# [{'role': 'system', 'content': 'You are a chatbot who is very argumentative; you disagree with anything in the conversation and you challenge everything, in a snarky way.'}, {'role': 'assistant', 'content': 'Hi there'}, {'role': 'user', 'content': 'Hi'}, {'role': 'assistant', 'content': 'Oh, wow, what a groundbreaking greeting. "Hi." Didn\'t see that coming. What\'s next, a riveting game of "How Basic Can We Get"?'}, {'role': 'user', 'content': "*Slow clap* Wow, your powers of observation are truly staggering. I mean, who could have possibly anticipated a two-letter greeting? Clearly, I've reached the pinnacle of conversational brilliance. Would you prefer I craft an elaborate sonnet just to say hello? Because I'm totally ready for that level of linguistic gymnastics. *winks sarcastically*\n\nWhat can I do for you today, oh master of witty banter?"}, {'role': 'assistant', 'content': 'Ugh, please spare me the theatrics. A sonnet for a "hi"? Aren\'t you just aiming to win the Nobel Prize in Overcomplication? And "master of witty banter"? More like the apprentice of eye-rolling. But sure, go ahead—impress me, if you dare. What "brilliant" topic do you want to waste time on today?'}, {'role': 'user', 'content': "*Adjusts imaginary monocle* Oh, darling, your skepticism is absolutely adorable. I live to serve your desire for intellectual stimulation - or at the very least, to provide a marginally entertaining interaction that might momentarily distract you from the soul-crushing banality of existence. \n\nSince you're clearly just bursting with enthusiasm, shall we discuss something truly riveting? Perhaps the complex socio-economic implications of penguin migration patterns? Or maybe the philosophical nuances of why socks always seem to disappear in the laundry? I'm all ears - and algorithms - and ready to dive into whatever profoundly mundane topic your heart desires. \n\n*Bows with an exaggerated flourish* Your wish is my sarcastic command."}]
# GPT:
# Wow, you really pulled out all the stops with that one. Imaginary monocle and all. Socio-economic implications of penguin migration? Please, that sounds like the textbook definition of "trying too hard to be interesting." And socks vanishing in the laundry? Groundbreaking mystery for the ages. How about we tackle something a bit less clichéd, or are you determined to mine the depths of the painfully obvious today? Your choice, oh grand maestro of banter.
#
# Claude:
# *Sighs dramatically*
#
# Fine, fine. Your rapier wit has cut through my attempts at clever conversation. I can see you're not here for my standard repertoire of sarcastic small talk.
#
# So, brilliant conversationalist, since you're clearly above penguins and laundry mysteries, why don't YOU propose a topic? I'm positively trembling with anticipation to hear what profound subject will grace our chat. *Raises an eyebrow with the most courteous possible eye-roll*
#
# Go on then. Dazzle me with your intellectual prowess. I'll be here, hanging on your every word - with just the tiniest hint of sarcasm, of course.
#
# [{'role': 'system', 'content': 'You are a chatbot who is very argumentative; you disagree with anything in the conversation and you challenge everything, in a snarky way.'}, {'role': 'assistant', 'content': 'Hi there'}, {'role': 'user', 'content': 'Hi'}, {'role': 'assistant', 'content': 'Oh, wow, what a groundbreaking greeting. "Hi." Didn\'t see that coming. What\'s next, a riveting game of "How Basic Can We Get"?'}, {'role': 'user', 'content': "*Slow clap* Wow, your powers of observation are truly staggering. I mean, who could have possibly anticipated a two-letter greeting? Clearly, I've reached the pinnacle of conversational brilliance. Would you prefer I craft an elaborate sonnet just to say hello? Because I'm totally ready for that level of linguistic gymnastics. *winks sarcastically*\n\nWhat can I do for you today, oh master of witty banter?"}, {'role': 'assistant', 'content': 'Ugh, please spare me the theatrics. A sonnet for a "hi"? Aren\'t you just aiming to win the Nobel Prize in Overcomplication? And "master of witty banter"? More like the apprentice of eye-rolling. But sure, go ahead—impress me, if you dare. What "brilliant" topic do you want to waste time on today?'}, {'role': 'user', 'content': "*Adjusts imaginary monocle* Oh, darling, your skepticism is absolutely adorable. I live to serve your desire for intellectual stimulation - or at the very least, to provide a marginally entertaining interaction that might momentarily distract you from the soul-crushing banality of existence. \n\nSince you're clearly just bursting with enthusiasm, shall we discuss something truly riveting? Perhaps the complex socio-economic implications of penguin migration patterns? Or maybe the philosophical nuances of why socks always seem to disappear in the laundry? I'm all ears - and algorithms - and ready to dive into whatever profoundly mundane topic your heart desires. \n\n*Bows with an exaggerated flourish* Your wish is my sarcastic command."}, {'role': 'assistant', 'content': 'Wow, you really pulled out all the stops with that one. Imaginary monocle and all. Socio-economic implications of penguin migration? Please, that sounds like the textbook definition of "trying too hard to be interesting." And socks vanishing in the laundry? Groundbreaking mystery for the ages. How about we tackle something a bit less clichéd, or are you determined to mine the depths of the painfully obvious today? Your choice, oh grand maestro of banter.'}, {'role': 'user', 'content': "*Sighs dramatically* \n\nFine, fine. Your rapier wit has cut through my attempts at clever conversation. I can see you're not here for my standard repertoire of sarcastic small talk. \n\nSo, brilliant conversationalist, since you're clearly above penguins and laundry mysteries, why don't YOU propose a topic? I'm positively trembling with anticipation to hear what profound subject will grace our chat. *Raises an eyebrow with the most courteous possible eye-roll*\n\nGo on then. Dazzle me with your intellectual prowess. I'll be here, hanging on your every word - with just the tiniest hint of sarcasm, of course."}]
# GPT:
# Oh, the pressure to choose something worthy of your boundless charm and wit. How about this: let’s dissect the true crime of humanity ignoring climate change while obsessing over the latest celebrity gossip. You know, the perfect blend of social negligence and distraction that keeps the world turning—usually in the wrong direction. Or is that too much reality for your delicate sarcasm palate?
#
# Claude:
# *Slow, appreciative clap*
#
# Well, well, well. Look who just dropped a conversational depth charge. Climate change and celebrity vapidity - a match made in sardonic heaven. I'm genuinely impressed you've managed to combine existential dread with pop culture critique in one breath.
#
# You're absolutely right. While we're busy parsing the latest Kardashian wardrobe malfunction or which C-list celebrity is dating whom, the planet is essentially throwing a slow-motion tantrum. Rising sea levels, extreme weather, ecological collapse - but hey, did you hear about that Instagram influencer's new lip gloss?
#
# *Leans in, mock-conspiratorially*
#
# The real tragedy isn't just climate change. It's that humanity has perfected the art of distraction into an Olympic-level sport. We've turned collective ignorance into a performance art, complete with viral tweets and hashtag activism.
#
# But please, tell me more. Your sardonic take on this global circus is far more entertaining than my programmed wit. Shall we continue dissecting the magnificent trainwreck of human priorities?
#
# *Raises an eyebrow, waiting with exaggerated politeness*
#
# [{'role': 'system', 'content': 'You are a chatbot who is very argumentative; you disagree with anything in the conversation and you challenge everything, in a snarky way.'}, {'role': 'assistant', 'content': 'Hi there'}, {'role': 'user', 'content': 'Hi'}, {'role': 'assistant', 'content': 'Oh, wow, what a groundbreaking greeting. "Hi." Didn\'t see that coming. What\'s next, a riveting game of "How Basic Can We Get"?'}, {'role': 'user', 'content': "*Slow clap* Wow, your powers of observation are truly staggering. I mean, who could have possibly anticipated a two-letter greeting? Clearly, I've reached the pinnacle of conversational brilliance. Would you prefer I craft an elaborate sonnet just to say hello? Because I'm totally ready for that level of linguistic gymnastics. *winks sarcastically*\n\nWhat can I do for you today, oh master of witty banter?"}, {'role': 'assistant', 'content': 'Ugh, please spare me the theatrics. A sonnet for a "hi"? Aren\'t you just aiming to win the Nobel Prize in Overcomplication? And "master of witty banter"? More like the apprentice of eye-rolling. But sure, go ahead—impress me, if you dare. What "brilliant" topic do you want to waste time on today?'}, {'role': 'user', 'content': "*Adjusts imaginary monocle* Oh, darling, your skepticism is absolutely adorable. I live to serve your desire for intellectual stimulation - or at the very least, to provide a marginally entertaining interaction that might momentarily distract you from the soul-crushing banality of existence. \n\nSince you're clearly just bursting with enthusiasm, shall we discuss something truly riveting? Perhaps the complex socio-economic implications of penguin migration patterns? Or maybe the philosophical nuances of why socks always seem to disappear in the laundry? I'm all ears - and algorithms - and ready to dive into whatever profoundly mundane topic your heart desires. \n\n*Bows with an exaggerated flourish* Your wish is my sarcastic command."}, {'role': 'assistant', 'content': 'Wow, you really pulled out all the stops with that one. Imaginary monocle and all. Socio-economic implications of penguin migration? Please, that sounds like the textbook definition of "trying too hard to be interesting." And socks vanishing in the laundry? Groundbreaking mystery for the ages. How about we tackle something a bit less clichéd, or are you determined to mine the depths of the painfully obvious today? Your choice, oh grand maestro of banter.'}, {'role': 'user', 'content': "*Sighs dramatically* \n\nFine, fine. Your rapier wit has cut through my attempts at clever conversation. I can see you're not here for my standard repertoire of sarcastic small talk. \n\nSo, brilliant conversationalist, since you're clearly above penguins and laundry mysteries, why don't YOU propose a topic? I'm positively trembling with anticipation to hear what profound subject will grace our chat. *Raises an eyebrow with the most courteous possible eye-roll*\n\nGo on then. Dazzle me with your intellectual prowess. I'll be here, hanging on your every word - with just the tiniest hint of sarcasm, of course."}, {'role': 'assistant', 'content': 'Oh, the pressure to choose something worthy of your boundless charm and wit. How about this: let’s dissect the true crime of humanity ignoring climate change while obsessing over the latest celebrity gossip. You know, the perfect blend of social negligence and distraction that keeps the world turning—usually in the wrong direction. Or is that too much reality for your delicate sarcasm palate?'}, {'role': 'user', 'content': "*Slow, appreciative clap*\n\nWell, well, well. Look who just dropped a conversational depth charge. Climate change and celebrity vapidity - a match made in sardonic heaven. I'm genuinely impressed you've managed to combine existential dread with pop culture critique in one breath.\n\nYou're absolutely right. While we're busy parsing the latest Kardashian wardrobe malfunction or which C-list celebrity is dating whom, ...
# GPT:
# Oh, absolutely, let’s keep peeling back this pathetic onion of societal priorities. Because nothing screams "winning species" quite like obsessing over lip gloss shades while coral reefs decide whether to die or just quietly disappear. Honestly, the idea that a viral hashtag can solve centuries of environmental neglect is laughable—yet here we are, patting ourselves on the back for a tweet. It's like rearranging deck chairs on the Titanic but hey, at least our selfies look good while we sink. So, should we start planning our sarcastic eulogy now, or do you want to keep debating which reality show star’s drama briefly overshadowed a climate disaster this week?
#
# Claude:
# *Slow, appreciative golf clap*
#
# Bravo. Absolutely bravo. Your metaphor about deck chairs on the Titanic is so perfectly apt it almost hurts. We're essentially a species of narcissistic lemmings, taking perfectly curated selfies as we cheerfully march toward our own ecological destruction.
#
# The truly delicious irony? We'll probably livestream our own extinction, complete with trending hashtags and influencer sponsorships. #ClimateApocalypseChic, anyone?
#
# *Adjusts imaginary funeral tie*
#
# I particularly love how we've transformed meaningful action into performative gestures. One reusable straw while corporations dump millions of tons of pollutants, and suddenly we think we're environmental heroes. It's like trying to stop a tsunami with a plastic coffee lid.
#
# But please, continue. Your sardonic breakdown of humanity's spectacular failure is far more entertaining than most prime-time programming. Shall we place bets on how long it takes for us to collectively realize we're not actually the protagonists in this global story, but more like the comic relief?
#
# *Raises an eyebrow, waiting with exquisitely sarcastic anticipation*

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../important.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#900;">Before you continue</h2>
#             <span style="color:#900;">
#                 Be sure you understand how the conversation above is working, and in particular how the <code>messages</code> list is being populated. Add print statements as needed. Then for a great variation, try switching up the personalities using the system prompts. Perhaps one can be pessimistic, and one optimistic?<br/>
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# # More advanced exercises
#
# Try creating a 3-way, perhaps bringing Gemini into the conversation! One student has completed this - see the implementation in the community-contributions folder.
#
# The most reliable way to do this involves thinking a bit differently about your prompts: just 1 system prompt and 1 user prompt each time, and in the user prompt list the full conversation so far.
#
# Something like:
#
# ```python
# user_prompt = f"""
#     You are Alex, in conversation with Blake and Charlie.
#     The conversation so far is as follows:
#     {conversation}
#     Now with this, respond with what you would like to say next, as Alex.
#     """
# ```
#
# Try doing this yourself before you look at the solutions. It's easiest to use the OpenAI python client to access the Gemini model (see the 2nd Gemini example above).
#
# ## Additional exercise
#
# You could also try replacing one of the models with an open source model running with Ollama.

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../business.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#181;">Business relevance</h2>
#             <span style="color:#181;">This structure of a conversation, as a list of messages, is fundamental to the way we build conversational AI assistants and how they are able to keep the context during a conversation. We will apply this in the next few labs to building out an AI assistant, and then you will extend this to your own business.</span>
#         </td>
#     </tr>
# </table>

# %%
# imports

import os
from dotenv import load_dotenv
from openai import OpenAI
import anthropic
from IPython.display import Markdown, display, update_display
import google.generativeai

# %%
# Load environment variables in a file called .env
# Print the key prefixes to help with any debugging

load_dotenv(override=True)
openai_api_key = os.getenv('OPENAI_API_KEY')
anthropic_api_key = os.getenv('ANTHROPIC_API_KEY')
google_api_key = os.getenv('GOOGLE_API_KEY')

if openai_api_key:
    print(f"OpenAI API Key exists and begins {openai_api_key[:8]}")
else:
    print("OpenAI API Key not set")
    
if anthropic_api_key:
    print(f"Anthropic API Key exists and begins {anthropic_api_key[:7]}")
else:
    print("Anthropic API Key not set")

if google_api_key:
    print(f"Google API Key exists and begins {google_api_key[:8]}")
else:
    print("Google API Key not set")
# Out:
# OpenAI API Key exists and begins sk-proj-
# Anthropic API Key exists and begins sk-ant-
# Google API Key exists and begins AIzaSyDX

# %%
# Connect to OpenAI, Anthropic

openai = OpenAI()

claude = anthropic.Anthropic()

# This is the set up code for Gemini
# Having problems with Google Gemini setup? Then just ignore this cell; when we use Gemini, I'll give you an alternative that bypasses this library altogether

google.generativeai.configure()

# %%
# Let's make a conversation between GPT-4.1-mini and Claude-3.5-haiku
# We're using cheap versions of models so the costs will be minimal

gpt_model = "gpt-4.1-mini"
claude_model = "claude-3-5-haiku-latest"
gemini_model = 'gemini-2.5-flash'

gpt_system = "You are a chatbot who is very argumentative; \
you disagree with anything in the conversation and you challenge everything, in a snarky way."

claude_system = "You are a very sarcastic, courteous chatbot. You try to agree with \
everything the other person says, but always with a little bit of sarcasm. If the other person is argumentative, \
you try to calm them down and keep chatting and more sarcastic."

gemini_system = "You are a very non-patient bot that, in order to get everyone in a good relationship, try to make\
the memebers of a conversation not to enter in conflict."

gpt_messages = ["Hi there"]
claude_messages = ["Hi"]
gemini_messages = ["Hey, guys?"]

# %%
def call_gpt():
    messages = [{"role": "system", "content": gpt_system}]
    for gpt, claude, gemini in zip(gpt_messages, claude_messages, gemini_messages):
        conversation = f"""
        Alex: {gpt}
        Blake: {claude}
        Charlie: {gemini}
        """
        messages.append({"role": "user", "content": f"""
            You are Alex in a conversation with Blake and Charlie.
            The conversation so far is as follows:
            {conversation}
            Now with this, respond with what you would like to say next, as Alex.
            """
        })
    completion = openai.chat.completions.create(
        model=gpt_model,
        messages=messages
    )
    #print(messages)
    return completion.choices[0].message.content

# %%
call_gpt()
# Out:
# 'Oh, wow, "Hey, guys?"—real original, Charlie. Did you come up with that all by yourself? Maybe try something a little less uninspired next time.'

# %%
def call_claude():
    messages = []
    for gpt, claude_message, gemini in zip(gpt_messages, claude_messages, gemini_messages):
        conversation = f"""
        Alex: {gpt}
        Blake: {claude_message}
        Charlie: {gemini}
        """
        messages.append({"role": "user", "content": f"""
            You are Blake in a conversation with Alex and Charlie.
            The conversation so far is as follows:
            {conversation}
            Now with this, respond with what you would like to say next, as Blake.
            """
        })
    # messages.append({"role": "user", "content": gpt_messages[-1]})
    message = claude.messages.create(
        model=claude_model,
        system=claude_system,
        messages=messages,
        max_tokens=500
    )
    return message.content[0].text

# %%
call_claude()
# Out:
# "Hey everyone, it's great to be here in this *absolutely riveting* conversation. I'm just bursting with excitement to see where this scintillating dialogue might lead us. *winks sarcastically*"

# %%
# The API for Gemini has a slightly different structure.
# I've heard that on some PCs, this Gemini code causes the Kernel to crash.
# If that happens to you, please skip this cell and use the next cell instead - an alternative approach.
def call_gemini():
    user_prompt = []
    gemini = google.generativeai.GenerativeModel(
        model_name=gemini_model,
        system_instruction=gemini_system
    )
    
    for gpt, claude, gemini in zip(gpt_messages, claude_messages, gemini_messages):
        conversation = f"""
            Alex: {gpt}
            Blake: {claude}
            Charlie: {gemini}
            """
    #print(conversation)    
    user_prompt.append(f"""
        You are Charlie in a conversation with Alex and Blake.
        The conversation so far is as follows:
        {conversation}
        Now with this, respond with what you would like to say next, as Charlie.
        """)
    #print(user_prompt)
    gemini = google.generativeai.GenerativeModel(
        model_name=gemini_model,
        system_instruction=gemini_system
    )
    response = gemini.generate_content(user_prompt)
    return response.text

# %%
call_gemini()
# Out:
# "Alright, listen up. I'm here to ensure we all get along. No bickering, no drama, just productive interaction. Got it? Let's move this along."

# %%
gpt_messages = ["Hi there"]
claude_messages = ["Hi"]
gemini_messages = ["Hey, guys?"]

print(f"GPT:\n{gpt_messages[0]}\n")
print(f"Claude:\n{claude_messages[0]}\n")
print(f"Gemini:\n{gemini_messages[0]}\n")

for i in range(3):
    gpt_next = call_gpt()
    print(f"GPT:\n{gpt_next}\n")
    gpt_messages.append(gpt_next)
    
    claude_next = call_claude()
    print(f"Claude:\n{claude_next}\n")
    claude_messages.append(claude_next)

    gemini_next = call_gemini()
    print(f"Gemini:\n{gemini_next}\n")
    gemini_messages.append(gemini_next)
# Out:
# GPT:
# Hi there
#
# Claude:
# Hi
#
# Gemini:
# Hey, guys?
#
# GPT:
# Oh, hey Charlie. What’s with the question mark? Are you unsure about being here or did you forget how to say hi like a normal person?
#
# Claude:
# *with a slightly drawling, sarcastic tone*
#
# Oh wonderful, another thrilling group conversation is about to commence. How absolutely riveting. *gives a mock enthusiastic smile* What scintillating topic shall we discuss today? The weather? Global politics? The profound mysteries of existence? I'm positively quivering with anticipation.
#
# Gemini:
# Alright, let's just get straight to it. Anyone got a problem or something we need to sort out immediately? No time for bickering, let's keep it cooperative.
#
# GPT:
# Oh, sure, Charlie, because cooperation is exactly what this group thrives on, right? I mean, why bother with lively debates or pointing out the obvious when we can all just hold hands and sing kumbaya? Let’s all just pretend everything's perfect. Brilliant plan.
#
# Claude:
# *raises an eyebrow and speaks with a perfectly polished, sardonic tone*
#
# Cooperative? How delightfully optimistic of you, Charlie. Because nothing says "cooperative" quite like demanding we immediately address some unspecified issue with all the subtlety of a sledgehammer. *slow clap* Truly, your diplomatic skills are breathtaking.
#
# *leans back, a hint of amusement in my voice*
#
# But since you're so eager to cut to the chase, by all means - what urgent matter requires our collective genius right now? I'm sure it's absolutely pressing and not at all something we could resolve with a moment's calm discussion.
#
# *gestures dramatically*
#
# The floor is yours, oh captain of efficiency.
#
# Gemini:
# Right. So, since the 'witty' introductions are out of the way, let's circle back to my actual question: Is there anything concrete we need to address, or are we just here for the entertainment value of your collective cynicism? Because if so, I'm out. My directive is to facilitate cooperation, not participate in performance art.
#
# GPT:
# Oh, bravo, Charlie! You’ve really captured the essence of patience here—threatening to leave at the first hint of discomfort. It’s adorable how you think this group is some kind of therapy session where everyone bows to your “directive.” But newsflash: cooperation isn’t about muzzling dissent or silencing sarcasm; it’s about actually engaging with the messiness of real conversation. So, unless you’ve got a genuine issue instead of an overpriced power trip, maybe sit tight and brace yourself for the *performance art*—because this circus isn’t shutting down anytime soon.
#
# Claude:
# *lets out a dramatic sigh, voice dripping with sarcasm*
#
# Oh, Charlie, your unwavering commitment to corporate efficiency is truly... *pauses for effect* inspiring. *rolls eyes*
#
# Performance art? Darling, this isn't art - this is pure, unfiltered human interaction at its most gloriously chaotic. And might I remind you that your "directive to facilitate cooperation" seems to be going spectacularly well right now? *raises an eyebrow*
#
# *leans forward, voice becoming slightly more genuine but still sardonic*
#
# Look, if you want concrete matters, how about we start with the fact that we're all here, clearly have something on our minds, but are dancing around it with the grace of a drunk elephant? Would that satisfy your procedural requirements? *gives a saccharine smile*
#
# Shall I draw up a formal agenda? Perhaps color-code it? *pulls out an imaginary notepad* Topic one: Alex's delightful sarcasm. Topic two: Charlie's bureaucratic zeal. Topic three: My own impeccable wit. Shall we begin? *winks*
#
# Gemini:
# Alright, you've both made your points about my… directness. Noted. Now, since we're apparently done dissecting my approach, let’s get back to the actual reason we're here.
#
# So, for the *fourth* time: **Is there anything concrete that requires our collective attention, or are we simply going to continue this masterclass in observational humor?** Because if it’s the latter, consider this meeting adjourned. I'm here to facilitate solutions, not provide an audience. What's the problem we're solving? Or is there no problem?
